# %%
X_features = list( credit_df.columns )
X_features.remove( 'status' )
X_features

# %%
credit_df_complete = pd.get_dummies( credit_df[X_features], drop_first = True )
#credit_df_complete = credit_df[X_features]

# %%
pd.set_option('display.max_columns', None)
credit_df_complete.head()

# %%
len( credit_df_complete.columns )

# %%
#Change the reponse variable to 0 = No Default and 1 = Default
Y = credit_df.status - 1
X = credit_df_complete

# %%
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.1, random_state = 42 )
print(credit_df_complete.shape)

# %%
mlp = MLPClassifier(random_state=42)
mlp.fit(X_train, y_train)

print('acc for training data: {:.3f}'.format(mlp.score(X_train, y_train)))
print('acc for test data: {:.3f}'.format(mlp.score(X_test, y_test)))

# %% [markdown]
# #### PLEASE ADD A FEW LINES CODE AS FOLLOWS TO IMPROVE THE MODEL, For example, you need to do data normalization, data standardization, and other data mining models.   IF YOU DO NOT HAVE CODE EXPERIENCE, PLEASE DISCUSS SEVERAL APPROACH TO MAKE IMPROVEMENT.

# %%
# Feature analysis # starting fresh

# %%
data = pd.read_csv( "german-credit-card.txt", delim_whitespace = True, header = None)
data.columns = columns
data
# Out:
#     checkin_acc  duration credit_history purpose  amount saving_acc  \
# 0           A11         6            A34     A43    1169        A65
# 1           A12        48            A32     A43    5951        A61
# 2           A14        12            A34     A46    2096        A61
# 3           A11        42            A32     A42    7882        A61
# 4           A11        24            A33     A40    4870        A61
# ..          ...       ...            ...     ...     ...        ...
# 995         A14        12            A32     A42    1736        A61
# 996         A11        30            A32     A41    3857        A61
# 997         A14        12            A32     A43     804        A61
# 998         A11        45            A32     A43    1845        A61
# 999         A12        45            A34     A41    4576        A62
#
#     present_emp_since  inst_rate personal_status other_debtors  ...  property  \
# ...

# %%
data = pd.get_dummies(data, drop_first = True)
data
# Out:
#      duration  amount  inst_rate  residing_since  age  num_credits  \
# 0           6    1169          4               4   67            2
# 1          48    5951          2               2   22            1
# 2          12    2096          2               3   49            1
# 3          42    7882          2               4   45            1
# 4          24    4870          3               4   53            2
# ..        ...     ...        ...             ...  ...          ...
# 995        12    1736          3               4   31            1
# 996        30    3857          4               4   40            1
# 997        12     804          4               4   38            1
# 998        45    1845          4               4   23            1
# 999        45    4576          3               4   27            1
#
#      dependents  status  checkin_acc_A12  checkin_acc_A13  ...  property_A124  \
# 0             1       1                0                0  ...              0
# ...

# %%
fig, axes = plt.subplots(2,3,figsize=(15,10))

sb.boxplot(x="inst_rate", data=data, ax=axes[0, 0])
sb.boxplot(x="duration", data=data, ax=axes[0, 1])
sb.boxplot(x="residing_since", data=data, ax=axes[0, 2])
sb.boxplot(x="age", data=data, ax=axes[1, 0])
sb.boxplot(x="num_credits", data=data, ax=axes[1, 1])
sb.boxplot(x="dependents", data=data, ax=axes[1, 2])


plt.show()

# %%
# calculating z score
z = np.abs(stats.zscore(X))
print(z)

# %%
threshold = 3
print(np.where(z > 3))

# %%
X = X[(z < 3).all(axis=1)]
X

# %%
data = data[data.duration <= 43]
data = data[data.age <= 55]
data = data[data.dependents <= 1]
# X = X[X.duration <= 43]

# %%
fig, axes = plt.subplots(2,3,figsize=(15,10))

sb.boxplot(x="inst_rate", data=data, ax=axes[0, 0])
sb.boxplot(x="duration", data=data, ax=axes[0, 1])
sb.boxplot(x="residing_since", data=data, ax=axes[0, 2])
sb.boxplot(x="age", data=data, ax=axes[1, 0])
sb.boxplot(x="num_credits", data=data, ax=axes[1, 1])
sb.boxplot(x="dependents", data=data, ax=axes[1, 2])


plt.show()

# %%
corr_analysis = data.corr()

# %%
credit_df

# %%
credit_df_complete1 = X.get(["duration", "amount", "num_credits", "residing_since", "age", "purpose_A41", "purpose_A410", "property_A124", "housing_A153", "job_A174", "telephone_A192"])

# %%
#Change the reponse variable to 0 = No Default and 1 = Default

# %%
# Out:
# (726, 49)

# %%
# mlp = MLPClassifier(random_state=42)
# mlp.fit(X_train, y_train)

# print('acc for training data: {:.3f}'.format(mlp.score(X_train, y_train)))
# print('acc for test data: {:.3f}'.format(mlp.score(X_test, y_test)))
